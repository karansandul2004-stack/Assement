# %%
# 6:1) Create a Python dictionary called playlist_prices with at least 5 key-value pairs where the key is a Spotify playlist 
#name (as a string) and the value is the playlist's price (as an integer). Print the dictionary.

playlist_prices = {
    "Top Hits": 299,
    "Chill Vibes": 849,
    "Workout Mix": 349,
    "LoFi Beats": 88,
    "Party Songs": 499
}

print("Playlist Prices:")
print(playlist_prices)
# Out:
# Playlist Prices:
# {'Top Hits': 299, 'Chill Vibes': 849, 'Workout Mix': 349, 'LoFi Beats': 88, 'Party Songs': 499}

# %%
# 6:2) Write a function update_playlist_price(playlist, new_price) that updates the price of a given playlist in 
# the playlist_prices dictionary. Test it by updating the price of any one playlist and printing the updated dictionary.

playlist_prices = {
    "Top Hits": 199,
    "Chill Vibes": 149,
    "Workout Mix": 249,
    "LoFi Beats": 99,
    "Party Songs": 299
}

# Using def function
def update_playlist_price(playlist, new_price):
    playlist_prices[playlist] = new_price

# Update the price of a playlist
update_playlist_price("Workout Mix", 549)

print("Updated Playlist Prices:",playlist_prices)
# Out:
# Updated Playlist Prices: {'Top Hits': 199, 'Chill Vibes': 149, 'Workout Mix': 549, 'LoFi Beats': 99, 'Party Songs': 299}

# %%
# 3). Remove a playlist from the playlist_prices dictionary using the del statement. Print the dictionary after deletion to confirm the change.

playlist_prices = {
    "Top Hits": 199,
    "Chill Vibes": 149,
    "Workout Mix": 249,
    "LoFi Beats": 99,
    "Party Songs": 299
}

# Remove a playlist using del
del playlist_prices["Top Hits"]

print("Playlist Prices after deletion:")
print(playlist_prices)
# Out:
# Playlist Prices after deletion:
# {'Chill Vibes': 149, 'Workout Mix': 249, 'LoFi Beats': 99, 'Party Songs': 299}

# %%
# 4). Given two sets: set1 contains the names of restaurants you have ordered from on Zomato, and set2 contains the names of restaurants you have ordered from on Swiggy, find and print the union and intersection of these sets.<br><br><em><strong>Hint:</strong> Use the union() and intersection() methods of Python sets.</em>

set1 = {"Domino's", "Burger King", "Subway", "KFC"}

# Ordered from Swiggy
set2 = {"KFC", "Pizza Hut", "Subway", "McDonald's"}

# Find the union of the two sets
all_restaurants = set1.union(set2)

# Find the intersection of the two sets
common_restaurants = set1.intersection(set2)

print("Restaurants ordered from either app (Union):")
print(all_restaurants)

print("\nRestaurants ordered from both apps (Intersection):")
print(common_restaurants)
# Out:
# Restaurants ordered from either app (Union):
# {'KFC', "Domino's", 'Subway', 'Burger King', "McDonald's", 'Pizza Hut'}
#
# Restaurants ordered from both apps (Intersection):
# {'KFC', 'Subway'}
