# %%
#14:1). Use open() in write mode to create a file called my_playlist.txt and write the names of 5 songs you listened to this week, each on a new line.

with open("my_playlist.txt", "w") as file:
    file.write("Kesariya\n")
    file.write("Believer\n")
    file.write("Shape of You\n")
    file.write("Blinding Lights\n")
    file.write("Excuses\n")

print("Playlist saved successfully in my_playlist.txt")
# Out:
# Playlist saved successfully in my_playlist.txt

# %%
#14:2).Read the my_playlist.txt file you created and print each song name in uppercase using Python file handling.

with open("my_playlist.txt", "r") as file:
    
    for song in file:
        print(song.strip().upper())
# Out:
# KESARIYA
# BELIEVER
# SHAPE OF YOU
# BLINDING LIGHTS
# EXCUSES

# %%
#14:3).Download a sample CSV file of IPL cricket match scores (or create your own with columns: Match, Team1, Team2, Winner), then write Python code to read the CSV and print the name of the winning team for each match.

import csv

# Open and read the CSV file
with open("C:/Users/Karandeep Singh/.cache/kagglehub/datasets/nowke9/ipldata/versions/2/matches.csv", "r", newline="") as file:
    reader = csv.DictReader(file)

    print("Winning Teams:")
    for row in reader:
        print(f"Match{row['city']}: {row['winner']}")
# Out:
# Winning Teams:
# MatchHyderabad: Sunrisers Hyderabad
# MatchPune: Rising Pune Supergiant
# MatchRajkot: Kolkata Knight Riders
# MatchIndore: Kings XI Punjab
# MatchBangalore: Royal Challengers Bangalore
# MatchHyderabad: Sunrisers Hyderabad
# MatchMumbai: Mumbai Indians
# MatchIndore: Kings XI Punjab
# MatchPune: Delhi Daredevils
# MatchMumbai: Mumbai Indians
# MatchKolkata: Kolkata Knight Riders
# MatchBangalore: Mumbai Indians
# MatchRajkot: Gujarat Lions
# MatchKolkata: Kolkata Knight Riders
# MatchDelhi: Delhi Daredevils
# MatchMumbai: Mumbai Indians
# MatchBangalore: Rising Pune Supergiant
# MatchDelhi: Kolkata Knight Riders
# MatchHyderabad: Sunrisers Hyderabad
# MatchRajkot: Royal Challengers Bangalore
# MatchHyderabad: Sunrisers Hyderabad
# MatchIndore: Mumbai Indians
# MatchKolkata: Gujarat Lions
# MatchMumbai: Mumbai Indians
# MatchPune: Rising Pune Supergiant
# MatchRajkot: Kings XI Punjab
# MatchKolkata: Kolkata Knight Riders
# MatchMumbai: Rising Pune Supergiant
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nowke9/ipldata")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 1.20M/1.20M [00:01<00:00, 973kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Karandeep Singh\.cache\kagglehub\datasets\nowke9\ipldata\versions\2

# %%
# !pip install kagglehub

# %%
import csv

# Open and read the CSV file
with open("C:/Users/Karandeep Singh/.cache/kagglehub/datasets/nowke9/ipldata/versions/2/deliveries.csv", "r", newline="") as file:
    reader = csv.DictReader(file)

    print("Winning Teams:")
    for row in reader:
        print(f"Match{row['batting_team']}: {row['batsman']}")
# Out:
# Winning Teams:
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: DA Warner
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: MC Henriques
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: S Dhawan
# MatchSunrisers Hyderabad: MC Henriques
# ...

# %%
#14:4.)Given a JSON file named user_profile.json containing details like username, followers, and bio (similar to an Instagram profile), use the json module to load the file and print the username and number of followers.

import json

with open("user_profile.json", "r") as file:
    profile = json.load(file)

print("Username:", profile["username"])
print("Followers:", profile["followers"])
# Out:
# Username: MAHK1234
# Followers: 1250

# %%
with open("user_profile.json", "r") as file:
    data = file.read()

print(data)
# Out:
# {
#     "username": "MAHK1234",
#     "followers": 1250,
#
# }

# %%
#14:5). Use pathlib to check if a file called zomato_orders.json exists in your current directory, and print an appropriate message if it is found or not.<br><br><em><strong>Hint:</strong> Use Path('zomato_orders.json').exists() from the pathlib module.</em>

from pathlib import Path

# Create a Path object for the file
file_path = Path("zomato_orders.json")

# Check if the file exists
if file_path.exists():
    print("zomato_orders.json found.")
else:
    print("zomato_orders.json not found.")
# Out:
# zomato_orders.json not found.
