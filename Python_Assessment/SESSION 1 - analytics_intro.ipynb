# %%
# write a cell that prints your name and your favorite app

data = (name := 'Karandeep Sandul', fav_app := 'Chrome') # walrus operator :=

# %%
print(data)
# Out:
# ('Karandeep Sandul', 'Chrome')

# %%
print('Welcome to Data Analytics with Python')
# Out:
# Welcome to Data Analytics with Python

# %%
import datetime

current_year = datetime.datetime.now().year
print("Current Year:", current_year)
# Out:
# Current Year: 2026
