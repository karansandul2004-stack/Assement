# %%
#7:1 
#Write a Python script that checks if a user's entered age is 18 or above and prints 'Eligible for IPL ticket booking' if true, otherwise prints 'Not eligible'.

age = int(input("Enter your age: "))

# Check eligibility for IPL ticket booking
if age >= 18:
    print("Eligible for IPL ticket booking")
else:
    print("Not eligible")
# Out:
# Enter your age:  18
# Eligible for IPL ticket booking

# %%
age = int(input("Enter your age: "))

# Check eligibility for IPL ticket booking
if age >= 18:
    print("Eligible for IPL ticket booking")
else:
    print("Not eligible")
# Out:
# Enter your age:  17
# Not eligible

# %%
#7:2Create a Python program that takes the number of followers as input and uses if, elif, and else to print 'Micro Influencer' if followers < 10,000, 'Rising Star' if between 10,000 and 100,000, and 'Celebrity' if above 100,000.

followers = int(input("Enter the number of followers: "))

# Classify the influencer
if followers < 5000:
    print("Micro Influencer")
elif followers <= 50000:
    print("Rising Star")
else:
    print("Celebrity")
# Out:
# Enter the number of followers:  1
# Micro Influencer

# %%
followers = int(input("Enter the number of followers: "))

# Classify the influencer
if followers < 5000:
    print("Micro Influencer")
elif followers <= 50000:
    print("Rising Star")
else:
    print("Celebrity")
# Out:
# Enter the number of followers:  50000
# Rising Star

# %%
followers = int(input("Enter the number of followers: "))

# Classify the influencer
if followers < 5000:
    print("Micro Influencer")
elif followers <= 50000:
    print("Rising Star")
else:
    print("Celebrity")
# Out:
# Enter the number of followers:  10000000
# Celebrity

# %%
#7:3 Build a Python script that asks the user for their Zomato order total and prints 'Apply Free Delivery' if total is above 299, 'Add more items for free delivery' if between 200 and 299, else 'Delivery charges apply'.

order_total = float(input("Enter your Zomato order total: ₹"))

# Check the order total and print the appropriate message
if order_total > 299:
    print("Apply Free Delivery")
elif 200 <= order_total <= 299:
    print("Add more items for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Enter your Zomato order total: ₹ 299
# Add more items for free delivery

# %%
order_total = float(input("Enter your Zomato order total: ₹"))

# Check the order total and print the appropriate message
if order_total > 299:
    print("Apply Free Delivery")
elif 200 <= order_total <= 299:
    print("Add more items for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Enter your Zomato order total: ₹ 300
# Apply Free Delivery

# %%
order_total = float(input("Enter your Zomato order total: ₹"))

# Check the order total and print the appropriate message
if order_total > 299:
    print("Apply Free Delivery")
elif 200 <= order_total <= 299:
    print("Add more items for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Enter your Zomato order total: ₹ 199
# Delivery charges apply

# %%
#7:4 Write a Python program using nested if statements: take a user's entered Flipkart cart value and payment method ('UPI', 'Card', 'Cash'). If the cart value is above 1000 and payment method is 'UPI', print 'Eligible for 10% cashback'; if above 1000 and payment is not 'UPI', print 'Eligible for 5% cashback'; else print 'No cashback'.

cart_value = float(input("Enter Flipkart cart value: ₹"))
payment_method = input("Enter payment method (UPI/Card/Cash): ")

# Check cashback eligibility using nested if
if cart_value > 1000:
    if payment_method.lower() == "upi":
        print("Eligible for 10% cashback")
    else:
        print("Eligible for 5% cashback")
else:
    print("No cashback")
# Out:
# Enter Flipkart cart value: ₹ 855
# Enter payment method (UPI/Card/Cash):  upi
# No cashback

# %%
cart_value = float(input("Enter Flipkart cart value: ₹"))
payment_method = input("Enter payment method (UPI/Card/Cash): ")

# Check cashback eligibility using nested if
if cart_value > 1000:
    if payment_method.lower() == "upi":
        print("Eligible for 10% cashback")
    else:
        print("Eligible for 5% cashback")
else:
    print("No cashback")
# Out:
# Enter Flipkart cart value: ₹ 1100
# Enter payment method (UPI/Card/Cash):  upi
# Eligible for 10% cashback

# %%
cart_value = float(input("Enter Flipkart cart value: ₹"))
payment_method = input("Enter payment method (UPI/Card/Cash): ")

# Check cashback eligibility using nested if
if cart_value > 1000:
    if payment_method.lower() == "upi":
        print("Eligible for 10% cashback")
    else:
        print("Eligible for 5% cashback")
else:
    print("No cashback")
# Out:
# Enter Flipkart cart value: ₹ 100000
# Enter payment method (UPI/Card/Cash):  card
# Eligible for 5% cashback
