# %%
#Create three variables in Python: user_name, fav_app, and daily_usage_hours. 
#Assign your own name, your favorite app (like Instagram or Zomato), and how many hours you use it daily.

# 2:1) Creating variables

user_name = "Karandeep Sandul"
fav_app = "Instagram"
daily_usage_hours = 3

print("User_Name:", user_name)
print("Fav_app:", fav_app)
print("Daily_usage_hours:", daily_usage_hours)
# Out:
# User_Name: Karandeep Sandul
# Fav_app: Instagram
# Daily_usage_hours: 3

# %%
#Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. 
#Print each variable and its data type using the type() function.

# 2:2) Flipkart products details

product_name = "PS5"
price = 80000.00
is_available = True

print("Product_name: ", product_name)
print("Price: ",price)
print("Is_available: ", is_available)

print("\nData Type:-")
print("Product_name: ", type(product_name))
print("Price: ",type(price))
print("Is_available: ", type(is_available))
# Out:
# Product_name:  PS5
# Price:  80000.0
# Is_available:  True
#
# Data Type:-
# Product_name:  <class 'str'>
# Price:  <class 'float'>
# Is_available:  <class 'bool'>

# %%
# Spotify Playlist Recommendation System
# This is a single-line comment.
# It explains individual steps of the program.

"""
This is a multi-line comment.

A Spotify playlist recommendation system might work like this:
1. Collect the user's listening history.
2. Recommend playlists that match the user's taste.
"""

#2:3) Spotify system

user_name = "Karandeep"
fav_category = "Cool"

print("User_name: ",user_name)
print("Fav_category: ",fav_category)
print("Recommended Playlist: Today's Top Hits")
# Out:
# User_name:  Karandeep
# Fav_category:  Cool
# Recommended Playlist: Today's Top Hits

# %%
#Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. 
#Follow Python naming conventions and print a sentence using all three variables, 
#like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

#2:4) Zomato Order

order_total = 330
delivery_region = "Bharuch"
discount_percent = 30

print(f"Order from {delivery_region} totals ₹{order_total} with {discount_percent}% discount.")
# Out:
# Order from Bharuch totals ₹330 with 30% discount.

# %%
#Write a Python script that intentionally mixes tabs and spaces for indentation, 
#then fix the script so it runs without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, 
#as per Python's best practices.</em>

#2:5) Mixes tabs

if True:
            print("Welcome to Python")
    print("This line indecates space intentationel")
# Out:
#   File <string>:9
#     print("This line indecates space intentationel")
#                                                     ^
# IndentationError: unindent does not match any outer indentation level

# %%
if True:               #when space remove
    print("Welcome to Python")
    print("This line indecates space intentationel")
# Out:
# Welcome to Python
# This line indecates space intentationel
